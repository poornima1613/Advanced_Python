# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1,2,3]

y = [1,4,8]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('Sample Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y)
plt.title('Sample Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend('This is sample data')
plt.show()

# %%
z=[2,4,6]

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.title('Sample Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(['This is sample1 data','This is sample2 data'])
plt.show()

# %%
sd=pd.read_csv('sampledata.csv')

sd
# Out:
#    cola  colb  colc
# 0     1     2    12
# 1     2     3    22
# 2     3     4     5
# 3     4     5    14
# 4     5     7     9

# %%
type(sd)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(sd.cola, sd.colb,'o')
plt.show()
